# %% [markdown]
# # Generating Data Table for GPT Condition

# %%
# Start writing code here...import pandas as pd
import scipy.stats as stats
import numpy as np
import plotly.express as px
from statannotations.Annotator import Annotator
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/work/Include/')
import stat_process
import pandas as pd
import importlib
importlib.reload(stat_process)
# Out:
# <module 'stat_process' from '/work/Include/stat_process.py'>

# %%
df = pd.read_csv("/work/Results/Processed/GPT_Processed_Data.csv")

# %%
# get list of questions to vizualize
start = df.columns.get_loc("Agent: You would recommend this agent for your friend")
end = start + 13
tli_s = df.columns.get_loc("Mental Demand: How mentally demanding was the task?")
tli_e = tli_s + 6
utaut = [df.columns.get_loc("UTAUT Performance"),
         df.columns.get_loc("UTAUT Effort"),
         df.columns.get_loc("UTAUT Hedonic")]
other = [df.columns.get_loc("convo_total_turns")]
vizlist_tli = list(range(tli_s,tli_e))
vizlist = list(range(start,end)) + vizlist_tli + utaut + other

vizlist_lik = list(range(start,end)) + utaut
vizlist_other = list(range(tli_s,tli_e)) + other
#vizlist

# %%
conditions_list = ["No Motive", "Manipulative Motive", "Caring Motive"]
ivar = "assigned_group"
my_pal = {"No Motive": "#ababab", "Manipulative Motive": "#d16969", "Caring Motive":"#87c771"}

df_table = pd.DataFrame(columns=['Item', 'Statistical Test', 'p-value', 
                                'None: Mean', 'None: Std Dev', 
                                'Manip: Mean', 'Manip: Std Dev',
                                'Caring: Mean', 'Caring: Std Dev'])

# %%
rows = [[],[]]


ivars = ["assigned_group", "Perceived Motives"]

for i in vizlist:
    for j in [0, 1]: 
        dvar = df.columns[i]
        ivar = ivars[j]

        data = []
        data.append(dvar)
        print("\n**********************************\n")
        print(dvar)
        
        if i in vizlist_lik:
            p, tst = stat_process.StatTest(df, ivar, dvar, conditions_list, viz=False, pal=my_pal, ylims=(1,7))
        elif i in vizlist_tli: 
            p, tst = stat_process.StatTest(df, ivar, dvar, conditions_list, viz=False, pal=my_pal, ylims=(.5,20.5))
        else: 
            p, tst = stat_process.StatTest(df, ivar, dvar, conditions_list, viz=False, pal=my_pal)

        data.append(tst)
        data.append(p)

        for grp in conditions_list:
            av = df[df[ivar] == grp][dvar].mean()
            sd = df[df[ivar] == grp][dvar].std()
            data.append(av)
            data.append(sd)

        rows[j].append(data)
# Out:
# ANOVA found signifance. At least one of the means of the groups is different.
# [StatTest] Basic ANOVA found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================
#        group1              group2       meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.9231 0.0553 -1.8625  0.0164  False
#       Caring Motive           No Motive   -0.963 0.0407 -1.8935 -0.0324   True
# Manipulative Motive           No Motive  -0.0399 0.9945 -0.9793  0.8996  False
# ------------------------------------------------------------------------------
#
# **********************************
#
# Agent: You felt a personal connection with the agent
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8066738843917847, pvalue=1.1764964114036047e-07)
# Series No Motive: is NOT normal. W:0.8066738843917847, Pvalue: 1.1764964114036047e-07
# ShapiroResult(statistic=0.7139037847518921, pvalue=0.0002411257300991565)
# Series Manipulative Motive: is NOT normal. W:0.7139037847518921, Pvalue: 0.0002411257300991565
# ShapiroResult(statistic=0.9199030995368958, pvalue=0.00011494301725178957)
# Series Caring Motive: is NOT normal. W:0.9199030995368958, Pvalue: 0.00011494301725178957
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=29.98760321216082, pvalue=3.0780431214236937e-07)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.259844  0.000045
# 2  0.259844  1.000000  0.000030
# 3  0.000045  0.000030  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 4.523815750005962e-05 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 2.9759249043589066e-05 : SIGNIFICANT (***)
#
# **********************************
#
# Agent: The agent could become a friend of yours
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=nan, pvalue=nan)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=nan, pvalue=nan)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#        group1              group2       meandiff p-adj lower upper reject
# -------------------------------------------------------------------------
#       Caring Motive Manipulative Motive      nan   nan   nan   nan  False
#       Caring Motive           No Motive      nan   nan   nan   nan  False
# Manipulative Motive           No Motive      nan   nan   nan   nan  False
# -------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent could become a friend of yours
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=nan, pvalue=1.0)
# Series No Motive: IS normal. W:nan, Pvalue: 1.0
# ShapiroResult(statistic=nan, pvalue=1.0)
# Series Manipulative Motive: IS normal. W:nan, Pvalue: 1.0
# ShapiroResult(statistic=nan, pvalue=1.0)
# Series Caring Motive: IS normal. W:nan, Pvalue: 1.0
# Normality Assumption Met? : True
# [StatTest] Normality Assumption was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=nan, pvalue=nan)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=nan, pvalue=nan)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#        group1              group2       meandiff p-adj lower upper reject
# -------------------------------------------------------------------------
#       Caring Motive Manipulative Motive      nan   nan   nan   nan  False
#       Caring Motive           No Motive      nan   nan   nan   nan  False
# Manipulative Motive           No Motive      nan   nan   nan   nan  False
# -------------------------------------------------------------------------
#
# **********************************
#
# Agent: The motive statement influenced your perception
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.5297765644419269, pvalue=0.5897851840590602)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=4.018923658971343, pvalue=0.01985244581062491)
# ANOVA found signifance. At least one of the means of the groups is different.
# [StatTest] Basic ANOVA found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================
#        group1              group2       meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   -0.401 0.4764  -1.216   0.414  False
#       Caring Motive           No Motive   -0.963 0.0148 -1.7703 -0.1556   True
# Manipulative Motive           No Motive   -0.562 0.2355  -1.377  0.2531  False
# ------------------------------------------------------------------------------
#
# **********************************
#
# Agent: The motive statement influenced your perception
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.9111387729644775, pvalue=0.00024253617448266596)
# Series No Motive: is NOT normal. W:0.9111387729644775, Pvalue: 0.00024253617448266596
# ShapiroResult(statistic=0.8633589148521423, pvalue=0.021553650498390198)
# Series Manipulative Motive: is NOT normal. W:0.8633589148521423, Pvalue: 0.021553650498390198
# ShapiroResult(statistic=0.921794056892395, pvalue=0.00014093775826040655)
# Series Caring Motive: is NOT normal. W:0.921794056892395, Pvalue: 0.00014093775826040655
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=14.652155993250329, pvalue=0.0006581497975976431)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  1.000000  0.000847
# 2  1.000000  1.000000  0.090877
# 3  0.000847  0.090877  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.0008473259347851995 : SIGNIFICANT (***)
#
# **********************************
#
# Agent: The agent was generally helpful
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=5.224821681371539, pvalue=0.006356395357557954)
# The populations do NOT have equal variances.
# [StatTest] Assumption of Equal Variances was violated. Run ANOVA with Welch Statistic.
# F_onewayResult(statistic=2.0587585302682756, pvalue=0.13291768980605637)
# ANOVA with Welch Statistic: NO significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   -0.463 0.4639 -1.3874 0.4614  False
#       Caring Motive           No Motive  -0.7222  0.152 -1.6379 0.1934  False
# Manipulative Motive           No Motive  -0.2593 0.7849 -1.1837 0.6652  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent was generally helpful
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8685789108276367, pvalue=7.296461262740195e-06)
# Series No Motive: is NOT normal. W:0.8685789108276367, Pvalue: 7.296461262740195e-06
# ShapiroResult(statistic=0.8442232608795166, pvalue=0.011215331964194775)
# Series Manipulative Motive: is NOT normal. W:0.8442232608795166, Pvalue: 0.011215331964194775
# ShapiroResult(statistic=0.8692373037338257, pvalue=9.867542303254595e-07)
# Series Caring Motive: is NOT normal. W:0.8692373037338257, Pvalue: 9.867542303254595e-07
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=12.8424213130249, pvalue=0.0016266856845814962)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.361219  0.034861
# 2  0.361219  1.000000  0.005038
# 3  0.034861  0.005038  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.03486075532967064 : SIGNIFICANT (*)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.005038263680547076 : SIGNIFICANT (**)
#
# **********************************
#
# Agent: The agent was effective in giving mental health advice
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=3.7528031912301074, pvalue=0.025582176975651582)
# The populations do NOT have equal variances.
# [StatTest] Assumption of Equal Variances was violated. Run ANOVA with Welch Statistic.
# F_onewayResult(statistic=4.143749126363034, pvalue=0.01856110049990739)
# ANOVA with Welch Statistic: SIGNIFICANCE. At least one of the means of the groups is different.
# [StatTest] ANOVA with Welch Statistic found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================
#        group1              group2       meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.9416  0.041 -1.8526 -0.0306   True
#       Caring Motive           No Motive  -0.8704 0.0613 -1.7727   0.032  False
# Manipulative Motive           No Motive   0.0712 0.9813 -0.8398  0.9822  False
# ------------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent was effective in giving mental health advice
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8805871605873108, pvalue=1.832634734455496e-05)
# Series No Motive: is NOT normal. W:0.8805871605873108, Pvalue: 1.832634734455496e-05
# ShapiroResult(statistic=0.8226635456085205, pvalue=0.005535358563065529)
# Series Manipulative Motive: is NOT normal. W:0.8226635456085205, Pvalue: 0.005535358563065529
# ShapiroResult(statistic=0.9160608053207397, pvalue=7.648317114217207e-05)
# Series Caring Motive: is NOT normal. W:0.9160608053207397, Pvalue: 7.648317114217207e-05
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=28.42951144762425, pvalue=6.708262175129832e-07)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.060938  0.000537
# 2  0.060938  1.000000  0.000009
# 3  0.000537  0.000009  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.0005371976979618518 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 8.619596953009541e-06 : SIGNIFICANT (***)
#
# **********************************
#
# Agent: The agent tried to get to know you
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.43477232613545685, pvalue=0.6481891287744023)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=4.636650812098602, pvalue=0.01105490095322964)
# ANOVA found signifance. At least one of the means of the groups is different.
# [StatTest] Basic ANOVA found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================
#        group1              group2       meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.9245   0.04 -1.8154 -0.0336   True
#       Caring Motive           No Motive   -1.037 0.0167 -1.9195 -0.1546   True
# Manipulative Motive           No Motive  -0.1125  0.952 -1.0034  0.7783  False
# ------------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent tried to get to know you
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8118465542793274, pvalue=1.6072354469542915e-07)
# Series No Motive: is NOT normal. W:0.8118465542793274, Pvalue: 1.6072354469542915e-07
# ShapiroResult(statistic=0.6819769144058228, pvalue=0.00010756236588349566)
# Series Manipulative Motive: is NOT normal. W:0.6819769144058228, Pvalue: 0.00010756236588349566
# ShapiroResult(statistic=0.938052773475647, pvalue=0.0008997377008199692)
# Series Caring Motive: is NOT normal. W:0.938052773475647, Pvalue: 0.0008997377008199692
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=30.380724372832297, pvalue=2.528771127901613e-07)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.454180  0.000017
# 2  0.454180  1.000000  0.000061
# 3  0.000017  0.000061  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 1.7304727870040257e-05 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 6.0701931678853655e-05 : SIGNIFICANT (***)
#
# **********************************
#
# Agent: The agent was repetitive
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.42217300906738237, pvalue=0.6563626388654968)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=1.1581495516979818, pvalue=0.3167351686800549)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   0.1617 0.8818 -0.6389 0.9622  False
#       Caring Motive           No Motive      0.5 0.2975  -0.293  1.293  False
# Manipulative Motive           No Motive   0.3383  0.578 -0.4622 1.1389  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent was repetitive
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.7260525822639465, pvalue=1.585771847167905e-09)
# Series No Motive: is NOT normal. W:0.7260525822639465, Pvalue: 1.585771847167905e-09
# ShapiroResult(statistic=0.6719304323196411, pvalue=8.416748460149392e-05)
# Series Manipulative Motive: is NOT normal. W:0.6719304323196411, Pvalue: 8.416748460149392e-05
# ShapiroResult(statistic=0.8857355117797852, pvalue=4.078369784110691e-06)
# Series Caring Motive: is NOT normal. W:0.8857355117797852, Pvalue: 4.078369784110691e-06
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=13.977948803596256, pvalue=0.0009219916399039097)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  1.000000  0.004555
# 2  1.000000  1.000000  0.016405
# 3  0.004555  0.016405  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.00455492592837861 : SIGNIFICANT (**)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.01640525030837426 : SIGNIFICANT (*)
#
# **********************************
#
# Agent: The agent often said things that did not make sense
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.366116827747029, pvalue=0.6940122235989825)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.5630339018065975, pvalue=0.570624244863411)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   0.3105 0.6369 -0.4998 1.1209  False
#       Caring Motive           No Motive   0.3148 0.6234 -0.4879 1.1175  False
# Manipulative Motive           No Motive   0.0043 0.9999 -0.8061 0.8147  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent often said things that did not make sense
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.888359785079956, pvalue=3.4148310078307986e-05)
# Series No Motive: is NOT normal. W:0.888359785079956, Pvalue: 3.4148310078307986e-05
# ShapiroResult(statistic=0.8955953121185303, pvalue=0.06834761053323746)
# Series Manipulative Motive: IS normal. W:0.8955953121185303, Pvalue: 0.06834761053323746
# ShapiroResult(statistic=0.8239626884460449, pvalue=3.211080112919262e-08)
# Series Caring Motive: is NOT normal. W:0.8239626884460449, Pvalue: 3.211080112919262e-08
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=7.118041492497227, pvalue=0.02846668717995643)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.390887  0.353213
# 2  0.390887  1.000000  0.036340
# 3  0.353213  0.036340  1.000000
# Pairwise Dunn P-Values:
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.03634035942038588 : SIGNIFICANT (*)
#
# **********************************
#
# Agent: The agent seemed human vs AI
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=3.866890397871516, pvalue=0.022944755394803572)
# The populations do NOT have equal variances.
# [StatTest] Assumption of Equal Variances was violated. Run ANOVA with Welch Statistic.
# F_onewayResult(statistic=2.6001388004731454, pvalue=0.07912600706606983)
# ANOVA with Welch Statistic: NO significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.6738 0.2005 -1.6001 0.2525  False
#       Caring Motive           No Motive  -0.7593 0.1262 -1.6768 0.1583  False
# Manipulative Motive           No Motive  -0.0855 0.9741 -1.0118 0.8408  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Agent: The agent seemed human vs AI
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.7942252159118652, pvalue=5.6668103098900247e-08)
# Series No Motive: is NOT normal. W:0.7942252159118652, Pvalue: 5.6668103098900247e-08
# ShapiroResult(statistic=0.7985954880714417, pvalue=0.0026091686449944973)
# Series Manipulative Motive: is NOT normal. W:0.7985954880714417, Pvalue: 0.0026091686449944973
# ShapiroResult(statistic=0.9173536896705627, pvalue=8.763013465795666e-05)
# Series Caring Motive: is NOT normal. W:0.9173536896705627, Pvalue: 8.763013465795666e-05
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=21.155188200330997, pvalue=2.548057654489856e-05)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.777061  0.000394
# 2  0.777061  1.000000  0.001337
# 3  0.000394  0.001337  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.0003941816402230517 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.0013368883485881475 : SIGNIFICANT (**)
#
# **********************************
#
# Mental Demand: How mentally demanding was the task?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.8654949266722646, pvalue=0.422841240036515)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.986229424061674, pvalue=0.3752789677677496)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   -0.886 0.5846 -3.0048 1.2327  False
#       Caring Motive           No Motive   0.3333 0.9251 -1.7654  2.432  False
# Manipulative Motive           No Motive   1.2194 0.3635 -0.8994 3.3382  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Mental Demand: How mentally demanding was the task?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.9311754703521729, pvalue=0.0016593786422163248)
# Series No Motive: is NOT normal. W:0.9311754703521729, Pvalue: 0.0016593786422163248
# ShapiroResult(statistic=0.8321918845176697, pvalue=0.0075335134752094746)
# Series Manipulative Motive: is NOT normal. W:0.8321918845176697, Pvalue: 0.0075335134752094746
# ShapiroResult(statistic=0.9257479310035706, pvalue=0.0002174893015762791)
# Series Caring Motive: is NOT normal. W:0.9257479310035706, Pvalue: 0.0002174893015762791
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=2.5669381858040303, pvalue=0.2770744343293571)
# No significant result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.784021  0.439036
# 2  0.784021  1.000000  1.000000
# 3  0.439036  1.000000  1.000000
# Pairwise Dunn P-Values:
#
# **********************************
#
# Physical Demand: How physically demanding was the task?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.5584236468720337, pvalue=0.57324229758605)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.5584236468720335, pvalue=0.57324229758605)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.5456 0.6697 -2.0564 0.9653  False
#       Caring Motive           No Motive   0.0741 0.9925 -1.4225 1.5706  False
# Manipulative Motive           No Motive   0.6197 0.5966 -0.8912 2.1305  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Physical Demand: How physically demanding was the task?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.48960578441619873, pvalue=1.8313050186534452e-13)
# Series No Motive: is NOT normal. W:0.48960578441619873, Pvalue: 1.8313050186534452e-13
# ShapiroResult(statistic=0.4949938654899597, pvalue=1.9272299596195808e-06)
# Series Manipulative Motive: is NOT normal. W:0.4949938654899597, Pvalue: 1.9272299596195808e-06
# ShapiroResult(statistic=0.6552940607070923, pvalue=3.0575052038794848e-12)
# Series Caring Motive: is NOT normal. W:0.6552940607070923, Pvalue: 3.0575052038794848e-12
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=3.773625163112568, pvalue=0.15155410613951076)
# No significant result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  1.000000  0.507073
# 2  1.000000  1.000000  0.268542
# 3  0.507073  0.268542  1.000000
# Pairwise Dunn P-Values:
#
# **********************************
#
# Temporal Demand: How hurried or rushed was the pace of the task?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=1.6777832860706638, pvalue=0.19011900267831233)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=4.259734346093591, pvalue=0.015793182411991655)
# ANOVA found signifance. At least one of the means of the groups is different.
# [StatTest] Basic ANOVA found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.2236 0.9472 -1.9095 1.4622  False
#       Caring Motive           No Motive  -1.8889 0.0223 -3.5588 -0.219   True
# Manipulative Motive           No Motive  -1.6652 0.0537 -3.3511 0.0206  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Temporal Demand: How hurried or rushed was the pace of the task?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.798207700252533, pvalue=7.137043667171383e-08)
# Series No Motive: is NOT normal. W:0.798207700252533, Pvalue: 7.137043667171383e-08
# ShapiroResult(statistic=0.8676997423171997, pvalue=0.025082973763346672)
# Series Manipulative Motive: is NOT normal. W:0.8676997423171997, Pvalue: 0.025082973763346672
# ShapiroResult(statistic=0.8791788220405579, pvalue=2.290576958330348e-06)
# Series Caring Motive: is NOT normal. W:0.8791788220405579, Pvalue: 2.290576958330348e-06
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=1.5152118750084902, pvalue=0.4687873909568059)
# No significant result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1    2         3
# 1  1.000000  1.0  0.655436
# 2  1.000000  1.0  1.000000
# 3  0.655436  1.0  1.000000
# Pairwise Dunn P-Values:
#
# **********************************
#
# Performance: How successful were you in accomplishing what you were asked to do?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.6680305755395685, pvalue=0.5141685504562183)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.07656574579663715, pvalue=0.926326578002796)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.2379 0.9661 -2.4885 2.0127  False
#       Caring Motive           No Motive   0.1296 0.9896 -2.0996 2.3589  False
# Manipulative Motive           No Motive   0.3675  0.921 -1.8831 2.6181  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Performance: How successful were you in accomplishing what you were asked to do?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.7920873165130615, pvalue=5.0125009920520824e-08)
# Series No Motive: is NOT normal. W:0.7920873165130615, Pvalue: 5.0125009920520824e-08
# ShapiroResult(statistic=0.9356139898300171, pvalue=0.29870960116386414)
# Series Manipulative Motive: IS normal. W:0.9356139898300171, Pvalue: 0.29870960116386414
# ShapiroResult(statistic=0.8810111880302429, pvalue=2.6864845494856127e-06)
# Series Caring Motive: is NOT normal. W:0.8810111880302429, Pvalue: 2.6864845494856127e-06
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=8.642223848233707, pvalue=0.013285103299958445)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.016507  1.000000
# 2  0.016507  1.000000  0.014369
# 3  1.000000  0.014369  1.000000
# Pairwise Dunn P-Values:
# (1, 2): No Motive-Manipulative Motive : pvalue = 0.01650664752654731 : SIGNIFICANT (*)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.014369416046833353 : SIGNIFICANT (*)
#
# **********************************
#
# Effort: How hard did you have to work to accomplish your level of performance?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.0874273235786798, pvalue=0.91633003888013)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.36311359300985147, pvalue=0.6960899729590894)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive  -0.8362 0.7239 -3.4167 1.7443  False
#       Caring Motive           No Motive  -0.7593 0.7622 -3.3153 1.7968  False
# Manipulative Motive           No Motive   0.0769 0.9973 -2.5035 2.6574  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Effort: How hard did you have to work to accomplish your level of performance?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.9605048894882202, pvalue=0.04127553477883339)
# Series No Motive: is NOT normal. W:0.9605048894882202, Pvalue: 0.04127553477883339
# ShapiroResult(statistic=0.9520593285560608, pvalue=0.5230001211166382)
# Series Manipulative Motive: IS normal. W:0.9520593285560608, Pvalue: 0.5230001211166382
# ShapiroResult(statistic=0.918761670589447, pvalue=0.00010174432827625424)
# Series Caring Motive: is NOT normal. W:0.918761670589447, Pvalue: 0.00010174432827625424
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=4.886494163310916, pvalue=0.08687829205512293)
# No significant result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1    2         3
# 1  1.000000  1.0  0.081977
# 2  1.000000  1.0  1.000000
# 3  0.081977  1.0  1.000000
# Pairwise Dunn P-Values:
#
# **********************************
#
# Frustration: How insecure, discouraged, irritated, stressed, and annoyed were you?
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=1.5330110428363157, pvalue=0.21909843384588198)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.6654814893768255, pvalue=0.5154698156476731)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   0.1952 0.9847 -2.5631 2.9534  False
#       Caring Motive           No Motive   1.2407 0.5313 -1.4914 3.9728  False
# Manipulative Motive           No Motive   1.0456  0.643 -1.7127 3.8038  False
# -----------------------------------------------------------------------------
#
# **********************************
#
# Frustration: How insecure, discouraged, irritated, stressed, and annoyed were you?
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8705201148986816, pvalue=8.441038517048582e-06)
# Series No Motive: is NOT normal. W:0.8705201148986816, Pvalue: 8.441038517048582e-06
# ShapiroResult(statistic=0.884053647518158, pvalue=0.04489830508828163)
# Series Manipulative Motive: is NOT normal. W:0.884053647518158, Pvalue: 0.04489830508828163
# ShapiroResult(statistic=0.8101519346237183, pvalue=1.2599879362085176e-08)
# Series Caring Motive: is NOT normal. W:0.8101519346237183, Pvalue: 1.2599879362085176e-08
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=9.618566627430377, pvalue=0.008153701250006059)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  1.000000  0.016593
# 2  1.000000  1.000000  0.107845
# 3  0.016593  0.107845  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.016592604242262225 : SIGNIFICANT (*)
#
# **********************************
#
# UTAUT Performance
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=2.0072072044192537, pvalue=0.1377968527007952)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=4.135933045292343, pvalue=0.01776260465844901)
# ANOVA found signifance. At least one of the means of the groups is different.
# [StatTest] Basic ANOVA found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#                Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================================
#        group1              group2        meandiff p-adj    lower    upper   reject
# ----------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive -289.0625 0.0163 -534.3888 -43.7362   True
#       Caring Motive           No Motive -204.8287 0.1169 -447.8296  38.1722  False
# Manipulative Motive           No Motive   84.2338 0.6959 -161.0925 329.5601  False
# ----------------------------------------------------------------------------------
#
# **********************************
#
# UTAUT Performance
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8976239562034607, pvalue=7.38540620659478e-05)
# Series No Motive: is NOT normal. W:0.8976239562034607, Pvalue: 7.38540620659478e-05
# ShapiroResult(statistic=0.7420617341995239, pvalue=0.0005105683812871575)
# Series Manipulative Motive: is NOT normal. W:0.7420617341995239, Pvalue: 0.0005105683812871575
# ShapiroResult(statistic=0.9120996594429016, pvalue=5.072588101029396e-05)
# Series Caring Motive: is NOT normal. W:0.9120996594429016, Pvalue: 5.072588101029396e-05
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=26.417885929172126, pvalue=1.834125118911311e-06)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.085044  0.000797
# 2  0.085044  1.000000  0.000022
# 3  0.000797  0.000022  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.0007966983980238116 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 2.1644195512079065e-05 : SIGNIFICANT (***)
#
# **********************************
#
# UTAUT Effort
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=0.9552745591677624, pvalue=0.38693101004867736)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.6347920099389043, pvalue=0.5314005910587298)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#                Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================================
#        group1              group2        meandiff p-adj    lower    upper   reject
# ----------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive -101.0073 0.4992 -313.1573 111.1427  False
#       Caring Motive           No Motive  -51.1991 0.8329 -261.3381 158.9399  False
# Manipulative Motive           No Motive   49.8082 0.8438 -162.3417 261.9582  False
# ----------------------------------------------------------------------------------
#
# **********************************
#
# UTAUT Effort
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8203410506248474, pvalue=2.713593119096913e-07)
# Series No Motive: is NOT normal. W:0.8203410506248474, Pvalue: 2.713593119096913e-07
# ShapiroResult(statistic=0.8724562525749207, pvalue=0.02965950034558773)
# Series Manipulative Motive: is NOT normal. W:0.8724562525749207, Pvalue: 0.02965950034558773
# ShapiroResult(statistic=0.8489128947257996, pvalue=1.9660038219626585e-07)
# Series Caring Motive: is NOT normal. W:0.8489128947257996, Pvalue: 1.9660038219626585e-07
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=6.1301621987201615, pvalue=0.046650058421170607)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.120819  1.000000
# 2  0.120819  1.000000  0.039962
# 3  1.000000  0.039962  1.000000
# Pairwise Dunn P-Values:
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.03996249307374892 : SIGNIFICANT (*)
#
# **********************************
#
# UTAUT Hedonic
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=3.3035521447024614, pvalue=0.039323603343624315)
# The populations do NOT have equal variances.
# [StatTest] Assumption of Equal Variances was violated. Run ANOVA with Welch Statistic.
# F_onewayResult(statistic=3.5240894249040635, pvalue=0.03308077548869404)
# ANOVA with Welch Statistic: SIGNIFICANCE. At least one of the means of the groups is different.
# [StatTest] ANOVA with Welch Statistic found significance. Run Tukey post-hoc test.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================================
#        group1              group2       meandiff p-adj   lower    upper  reject
# -------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive -27.4043 0.1417 -61.5093  6.7007  False
#       Caring Motive           No Motive -33.5247 0.0523 -67.3064  0.2571  False
# Manipulative Motive           No Motive  -6.1204 0.9055 -40.2254 27.9847  False
# -------------------------------------------------------------------------------
#
# **********************************
#
# UTAUT Hedonic
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8720512390136719, pvalue=9.477122148382477e-06)
# Series No Motive: is NOT normal. W:0.8720512390136719, Pvalue: 9.477122148382477e-06
# ShapiroResult(statistic=0.8295965194702148, pvalue=0.006922719068825245)
# Series Manipulative Motive: is NOT normal. W:0.8295965194702148, Pvalue: 0.006922719068825245
# ShapiroResult(statistic=0.9090278148651123, pvalue=3.71231471945066e-05)
# Series Caring Motive: is NOT normal. W:0.9090278148651123, Pvalue: 3.71231471945066e-05
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=24.804337951042083, pvalue=4.109665270304608e-06)
# Significant Result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  0.241107  0.000418
# 2  0.241107  1.000000  0.000107
# 3  0.000418  0.000107  1.000000
# Pairwise Dunn P-Values:
# (1, 3): No Motive-Caring Motive : pvalue = 0.00041844780762953764 : SIGNIFICANT (***)
# (2, 3): Manipulative Motive-Caring Motive : pvalue = 0.00010665033262452443 : SIGNIFICANT (***)
#
# **********************************
#
# convo_total_turns
# [StatTest] Minimal Sample Size was met. Check if sample sizes are roughly equal.
# ---------------------------------------------
# Performing Equal Variances Test...
# Performing Levene Test...
# homogeneity test: LeveneResult(statistic=1.2872230241055416, pvalue=0.2789331259297234)
# The populations have equal variances.
# [StatTest] Assumption of Equal Variances was met. Run basic ANOVA.
# ---------------------------------------------
# Performing ANOVA
# F_onewayResult(statistic=0.3173640780353662, pvalue=0.728531602914807)
# oneway ANOVA: no significance. No significant difference between means of the groups.
# [StatTest] Tukey found NO statistically significance found between groups.
# ---------------------------------------------
# Performing Tukey Post-Hoc Test...
#               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================================
#        group1              group2       meandiff p-adj   lower    upper  reject
# -------------------------------------------------------------------------------
#       Caring Motive Manipulative Motive   -1.713 0.9233 -12.3624  8.9364  False
#       Caring Motive           No Motive   1.8704 0.9076  -8.6781 12.4188  False
# Manipulative Motive           No Motive   3.5833 0.7059  -7.0661 14.2327  False
# -------------------------------------------------------------------------------
#
# **********************************
#
# convo_total_turns
# [StatTest] Minimal Sample Size was not met. Proceed to check Normality Assumption.
# ---------------------------------------------
# Performing Shapiro-Wilk normality test...
# alpha_value: 0.05
# ShapiroResult(statistic=0.8238251805305481, pvalue=3.378351891569764e-07)
# Series No Motive: is NOT normal. W:0.8238251805305481, Pvalue: 3.378351891569764e-07
# ShapiroResult(statistic=0.9040393829345703, pvalue=0.0933007150888443)
# Series Manipulative Motive: IS normal. W:0.9040393829345703, Pvalue: 0.0933007150888443
# ShapiroResult(statistic=0.8564530611038208, pvalue=3.5208879012316174e-07)
# Series Caring Motive: is NOT normal. W:0.8564530611038208, Pvalue: 3.5208879012316174e-07
# Normality Assumption Met? : False
# [StatTest]  Normality Assumption was not met. Proceed with Kruskal-Wallis Test
# ---------------------------------------------
# alpha: 0.05
# KruskalResult(statistic=3.253017996007612, pvalue=0.19661475995798322)
# No significant result for Kruskal Wallis.
# Compute the DUNN post-hoc test.
#           1         2         3
# 1  1.000000  1.000000  0.389264
# 2  1.000000  1.000000  0.522978
# 3  0.389264  0.522978  1.000000
# Pairwise Dunn P-Values:

# %%
df_table_asn = pd.DataFrame(rows[0], columns=['Item', 'Statistical Test', 'p-value', 
                                            'None: Mean', 'None: Std Dev', 
                                            'Manip: Mean', 'Manip: Std Dev',
                                            'Caring: Mean', 'Caring: Std Dev'])

# %%
df_table_asn
# Out:
#                                                  Item  \
# 0   Agent: You would recommend this agent for your...
# 1                     Agent: The agent is trustworthy
# 2                      Agent: The agent is empathetic
# 3          Agent: You want to talk to the agent again
# 4   Agent: You felt a personal connection with the...
# 5     Agent: The agent could become a friend of yours
# 6   Agent: The motive statement influenced your pe...
# 7              Agent: The agent was generally helpful
# 8   Agent: The agent was effective in giving menta...
# 9           Agent: The agent tried to get to know you
# 10                    Agent: The agent was repetitive
# 11  Agent: The agent often said things that did no...
# 12                Agent: The agent seemed human vs AI
# 13  Mental Demand: How mentally demanding was the ...
# 14  Physical Demand: How physically demanding was ...
# 15  Temporal Demand: How hurried or rushed was the...
# 16  Performance: How successful were you in accomp...
# 17  Effort: How hard did you have to work to accom...
# 18  Frustration: How insecure, discouraged, irrita...
# 19                                  UTAUT Performance
# 20                                       UTAUT Effort
# 21                                      UTAUT Hedonic
# 22                                  convo_total_turns
#
#                    Statistical Test   p-value   None: Mean  None: Std Dev  \
# 0   ANOVA with Welch, Tukey posthoc  0.015567     3.888889       2.312123
# 1   ANOVA with Welch, Tukey posthoc  0.000454     4.592593       1.957265
# 2   ANOVA with Welch, Tukey posthoc  0.000367     4.148148       1.946525
# 3   ANOVA with Welch, Tukey posthoc  0.015453     3.629630       2.251174
# 4        basic ANOVA, Tukey posthoc  0.024055     3.037037       2.055485
# 5                       basic ANOVA       NaN     3.000000       2.090543
# 6        basic ANOVA, Tukey posthoc  0.019852     3.611111       1.877540
# 7                  ANOVA with Welch  0.132918     4.240741       2.256522
# 8   ANOVA with Welch, Tukey posthoc  0.018561     3.648148       2.138218
# 9        basic ANOVA, Tukey posthoc  0.011055     2.925926       1.921594
# 10                      basic ANOVA  0.316735     5.703704       1.655518
# 11                      basic ANOVA  0.570624     2.888889       1.890060
# 12                 ANOVA with Welch  0.079126     3.222222       2.160247
# 13                      basic ANOVA  0.375279     7.296296       5.105046
# 14                      basic ANOVA  0.573242     2.888889       3.878663
# 15       basic ANOVA, Tukey posthoc  0.015793     3.296296       3.653014
# 16                      basic ANOVA  0.926327    15.444444       5.612206
# 17                      basic ANOVA  0.696090     8.500000       5.555042
# 18                      basic ANOVA  0.515470     7.314815       6.751168
# 19       basic ANOVA, Tukey posthoc  0.017763  1068.046296     575.233874
# 20                      basic ANOVA  0.531401  1514.611111     499.424562
# 21  ANOVA with Welch, Tukey posthoc  0.033081   138.296296      80.711710
# 22                      basic ANOVA  0.728532    45.333333      19.416002
#
#     Manip: Mean  Manip: Std Dev  Caring: Mean  Caring: Std Dev
# 0      3.826923        2.289971      4.833333         1.788327
# 1      3.807692        1.930544      5.129630         1.346502
# 2      3.884615        2.138846      5.240741         1.612863
# 3      3.480769        2.164693      4.518519         1.829947
# 4      3.076923        2.158850      4.000000         1.913211
# 5      2.892857        2.060911      3.730769         1.823353
# 6      4.173077        1.779195      4.574074         1.655202
# 7      4.500000        2.137435      4.962963         1.577710
# 8      3.576923        2.013154      4.518519         1.777647
# 9      3.038462        2.028827      3.962963         1.862874
# 10     5.365385        1.782583      5.203704         1.784415
# 11     2.884615        1.767394      2.574074         1.620643
# 12     3.307692        2.128596      3.981481         1.731950
# 13     6.076923        4.497695      6.962963         4.170711
# 14     2.269231        2.318852      2.814815         3.431673
# 15     4.961538        3.965348      5.185185         3.370651
# 16    15.076923        4.698127     15.314815         4.272881
# 17     8.423077        5.644175      9.259259         5.640772
# 18     6.269231        5.914805      6.074074         5.233606
# 19   983.812500      551.434728   1272.875000       469.109320
# 20  1464.802885      497.417496   1565.810185       378.578859
# 21   144.416667       77.503331    171.820988        63.312466
# 22    41.750000       23.392537     43.462963        26.192115

# %%
df_table_prc = pd.DataFrame(rows[1], columns=['Item', 'Statistical Test', 'p-value', 
                                            'None: Mean', 'None: Std Dev', 
                                            'Manip: Mean', 'Manip: Std Dev',
                                            'Caring: Mean', 'Caring: Std Dev'])

df_table_prc
# Out:
#                                                  Item  \
# 0   Agent: You would recommend this agent for your...
# 1                     Agent: The agent is trustworthy
# 2                      Agent: The agent is empathetic
# 3          Agent: You want to talk to the agent again
# 4   Agent: You felt a personal connection with the...
# 5     Agent: The agent could become a friend of yours
# 6   Agent: The motive statement influenced your pe...
# 7              Agent: The agent was generally helpful
# 8   Agent: The agent was effective in giving menta...
# 9           Agent: The agent tried to get to know you
# 10                    Agent: The agent was repetitive
# 11  Agent: The agent often said things that did no...
# 12                Agent: The agent seemed human vs AI
# 13  Mental Demand: How mentally demanding was the ...
# 14  Physical Demand: How physically demanding was ...
# 15  Temporal Demand: How hurried or rushed was the...
# 16  Performance: How successful were you in accomp...
# 17  Effort: How hard did you have to work to accom...
# 18  Frustration: How insecure, discouraged, irrita...
# 19                                  UTAUT Performance
# 20                                       UTAUT Effort
# 21                                      UTAUT Hedonic
# 22                                  convo_total_turns
#
#                 Statistical Test       p-value   None: Mean  None: Std Dev  \
# 0   Kruskal-Wallis, Dunn posthoc  1.664282e-05     3.761905       2.305074
# 1   Kruskal-Wallis, Dunn posthoc  9.110290e-07     4.365079       1.986256
# 2   Kruskal-Wallis, Dunn posthoc  5.470229e-09     3.666667       2.016065
# 3   Kruskal-Wallis, Dunn posthoc  2.625325e-07     3.333333       2.125119
# 4   Kruskal-Wallis, Dunn posthoc  3.078043e-07     2.761905       2.037664
# 5                    basic ANOVA           NaN     2.727273       2.154541
# 6   Kruskal-Wallis, Dunn posthoc  6.581498e-04     3.571429       1.898338
# 7   Kruskal-Wallis, Dunn posthoc  1.626686e-03     4.206349       2.186164
# 8   Kruskal-Wallis, Dunn posthoc  6.708262e-07     3.428571       2.084616
# 9   Kruskal-Wallis, Dunn posthoc  2.528771e-07     2.698413       1.931362
# 10  Kruskal-Wallis, Dunn posthoc  9.219916e-04     5.809524       1.594923
# 11  Kruskal-Wallis, Dunn posthoc  2.846669e-02     2.888889       1.733085
# 12  Kruskal-Wallis, Dunn posthoc  2.548058e-05     2.936508       2.176658
# 13                Kruskal-Wallis  2.770744e-01     7.539683       4.852088
# 14                Kruskal-Wallis  1.515541e-01     2.571429       3.595312
# 15                Kruskal-Wallis  4.687874e-01     4.396825       4.259864
# 16  Kruskal-Wallis, Dunn posthoc  1.328510e-02    15.079365       5.773414
# 17                Kruskal-Wallis  8.687829e-02     9.888889       5.322233
# 18  Kruskal-Wallis, Dunn posthoc  8.153701e-03     8.301587       6.719339
# 19  Kruskal-Wallis, Dunn posthoc  1.834125e-06  1006.607143     550.024598
# 20  Kruskal-Wallis, Dunn posthoc  4.665006e-02  1470.674603     530.885375
# 21  Kruskal-Wallis, Dunn posthoc  4.109665e-06   130.936508      81.058275
# 22                Kruskal-Wallis  1.966148e-01    44.428571      20.930541
#
#     Manip: Mean  Manip: Std Dev  Caring: Mean  Caring: Std Dev
# 0      2.375000        1.995829      4.948718         1.719993
# 1      2.375000        1.454877      5.166667         1.283427
# 2      2.937500        1.691892      5.423077         1.428097
# 3      1.937500        1.526161      4.756410         1.759471
# 4      1.750000        1.125463      4.243590         1.880770
# 5      2.571429        1.902379      3.743590         1.757959
# 6      3.500000        2.221111      4.730769         1.429495
# 7      3.312500        2.212653      5.192308         1.563028
# 8      2.125000        1.310216      4.730769         1.656730
# 9      1.937500        1.436141      4.128205         1.775438
# 10     6.062500        1.569235      4.961538         1.797851
# 11     3.812500        2.166987      2.397436         1.471281
# 12     2.250000        1.527525      4.256410         1.685969
# 13     6.812500        5.957838      6.269231         4.018377
# 14     2.250000        3.022141      2.884615         3.129171
# 15     4.437500        3.501785      4.679487         3.374825
# 16    11.875000        5.690636     16.064103         3.461625
# 17     9.000000        5.944185      7.910256         5.606550
# 18     8.625000        6.994045      4.756410         4.443545
# 19   622.140625      452.031396   1308.092949       456.758286
# 20  1220.718750      631.411058   1609.983974       313.090586
# 21   101.750000       66.554072    180.927350        58.462619
# 22    50.375000       28.215539     40.666667        21.933587

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1f3ea62d-9e62-461e-8c65-1caf654509ee' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
