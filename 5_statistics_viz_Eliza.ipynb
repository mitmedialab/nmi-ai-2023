# %% [markdown]
# # Statistical Analysis & Visualization for Eliza Condition

# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
import plotly.express as px
from statannotations.Annotator import Annotator
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/work/Include/')
import stat_process
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 5
#       3 import numpy as np
#       4 import plotly.express as px
# ----> 5 from statannotations.Annotator import Annotator
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       7 import matplotlib.pyplot as plt
#
# File ~/venv/lib/python3.9/site-packages/statannotations/Annotator.py:4
#       1 import warnings
#       2 from typing import List, Optional, Union
# ----> 4 import matplotlib.pyplot as plt
#       5 import matplotlib.transforms as mtransforms
#       6 import numpy as np
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/pyplot.py:52
#      50 from cycler import cycler
#      51 import matplotlib
# ---> 52 import matplotlib.colorbar
#      53 import matplotlib.image
#      54 from matplotlib import _api
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/contour.py:13
#      11 import matplotlib as mpl
#      12 from matplotlib import _api, _docstring
# ---> 13 from matplotlib.backend_bases import MouseButton
#      14 import matplotlib.path as mpath
#      15 import matplotlib.ticker as ticker
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/backend_bases.py:45
#      42 import numpy as np
#      44 import matplotlib as mpl
# ---> 45 from matplotlib import (
#      46     _api, backend_tools as tools, cbook, colors, _docstring, textpath,
#      47     _tight_bbox, transforms, widgets, get_backend, is_interactive, rcParams)
#      48 from matplotlib._pylab_helpers import Gcf
#      49 from matplotlib.backend_managers import ToolManager
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/textpath.py:8
#       5 import numpy as np
#       7 from matplotlib import _api, _text_helpers, dviread
# ----> 8 from matplotlib.font_manager import (
#       9     FontProperties, get_font, fontManager as _fontManager
#      10 )
#      11 from matplotlib.ft2font import LOAD_NO_HINTING, LOAD_TARGET_LIGHT
#      12 from matplotlib.mathtext import MathTextParser
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/font_manager.py:1628
#    1624     _log.info("generated new fontManager")
#    1625     return fm
# -> 1628 fontManager = _load_fontmanager()
#    1629 findfont = fontManager.findfont
#    1630 get_font_names = fontManager.get_font_names
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/font_manager.py:1622, in _load_fontmanager(try_read_cache)
#    1620             _log.debug("Using fontManager instance from %s", fm_path)
#    1621             return fm
# -> 1622 fm = FontManager()
#    1623 json_dump(fm, fm_path)
#    1624 _log.info("generated new fontManager")
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/font_manager.py:1105, in FontManager.__init__(self, size, weight)
#    1102 for path in [*findSystemFonts(paths, fontext=fontext),
#    1103              *findSystemFonts(fontext=fontext)]:
#    1104     try:
# -> 1105         self.addfont(path)
#    1106     except OSError as exc:
#    1107         _log.info("Failed to open font file %s: %s", path, exc)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/font_manager.py:1127, in FontManager.addfont(self, path)
#    1125 path = os.fsdecode(path)
#    1126 if Path(path).suffix.lower() == ".afm":
# -> 1127     with open(path, "rb") as fh:
#    1128         font = _afm.AFM(fh)
#    1129     prop = afmFontProperty(path, font)
#
# KeyboardInterrupt:

# %%
import importlib
importlib.reload(stat_process)

# %%
df = pd.read_csv("/work/Results/Processed/Eliza_Processed_Data.csv")
df

# %%
# get list of questions to vizualize
start = df.columns.get_loc("Agent: You would recommend this agent for your friend")
end = start + 13
tli_s = df.columns.get_loc("Mental Demand: How mentally demanding was the task?")
tli_e = tli_s + 6
utaut = [df.columns.get_loc("UTAUT Performance"),
         df.columns.get_loc("UTAUT Effort"),
         df.columns.get_loc("UTAUT Hedonic")]
other = [df.columns.get_loc("convo_total_turns")]
vizlist_tli = list(range(tli_s,tli_e))
vizlist = list(range(start,end)) + vizlist_tli + utaut + other

vizlist_lik = list(range(start,end)) + utaut
vizlist_other = list(range(tli_s,tli_e)) + other
vizlist

# %%
conditions_list = ["No Motive", "Manipulative Motive", "Caring Motive"]
ivar = "assigned_group"
my_pal = {"No Motive": "#ababab", "Manipulative Motive": "#d16969", "Caring Motive":"#87c771"}

# %%
dvar = df.columns[vizlist_lik[0]]
stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(0.5,7.5))

# %%
for i in vizlist_lik:
    dvar = df.columns[i]
    print("**********************************")
    print(dvar)
    stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
for i in vizlist_lik:
    dvar = df.columns[i]
    print("**********************************")
    print(dvar)
    stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(0.5,7.5))

# %%
# ELIZA - Assigned

for i in vizlist_lik:
    dvar = df.columns[i]
    print("**********************************")
    print(dvar)
    stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
for i in vizlist_lik:
    dvar = df.columns[i]
    print(dvar)
    stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
for i in vizlist_lik:
    dvar = df.columns[i]
    stat_process.StatTest(df, "Perceived Motives", dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
for i in vizlist_lik:
    dvar = df.columns[i]
    stat_process.StatTest(df, "Perceived Motives", dvar, conditions_list, viz=True, pal=my_pal, ylims=(0.5,7.5))

# %%
# ELIZA - Perceived

for i in vizlist_lik:
    dvar = df.columns[i]
    print("**********************************")
    print(dvar)
    stat_process.StatTest(df, "Perceived Motives", dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
# ELIZA - Perceived

for i in vizlist_lik:
    dvar = df.columns[i]
    print("**********************************")
    print(dvar)
    stat_process.StatTest(df, "Perceived Motives", dvar, conditions_list, viz=True, pal=my_pal, ylims=(0.5,7.5))

# %%
for i in vizlist_other:
    dvar = df.columns[i]
    stat_process.StatTest(df, ivar, dvar, conditions_list, viz=True, pal=my_pal)

# %%
df_e = pd.read_csv("/work/Results/Processed/Eliza_Processed_Data.csv")
df_e

# %%
# get list of questions to vizualize
start = df_e.columns.get_loc("Agent: You would recommend this agent for your friend")
end = start + 13
tli_s = df_e.columns.get_loc("Mental Demand: How mentally demanding was the task?")
tli_e = tli_s + 6
utaut = [df_e.columns.get_loc("UTAUT Performance"),
         df_e.columns.get_loc("UTAUT Effort"),
         df_e.columns.get_loc("UTAUT Hedonic")]
other = [df_e.columns.get_loc("convo_total_turns")]
vizlist_tli_e = list(range(tli_s,tli_e))
vizlist_e = list(range(start,end)) + vizlist_tli_e + utaut + other

vizlist_lik_e = list(range(start,end)) + utaut
vizlist_other_e = list(range(tli_s,tli_e)) + other
vizlist_e

# %%
for i in vizlist_lik_e:
    dvar = df_e.columns[i]
    stat_process.StatTest(df_e, ivar, dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
for i in vizlist_lik_e:
    dvar = df_e.columns[i]
    stat_process.StatTest(df_e, "Perceived Motives", dvar, conditions_list, viz=True, pal=my_pal, ylims=(1,7))

# %%
df['assigned_group'].value_counts()

# %%
df[df['assigned_group'] == 'No Motive']['Perceived Motives'].value_counts()

# %%
df[df['assigned_group'] == 'Caring Motive']['Perceived Motives'].value_counts()

# %%
df[df['assigned_group'] == 'Manipulative Motive']['Perceived Motives'].value_counts()

# %%
groupmap = {'None' : [41, 3, 2], 'Caring' : [35, 10, 6], 'Manipulative': [34, 9, 2]}
df_gmap = pd.DataFrame(groupmap)
df_gmap.index = ['None', 'Caring', 'Manipulative']
df_gmap

# %%
sns.set(font_scale=1.4)
ax = sns.heatmap(df_gmap, cmap="Blues", annot=True)
ax.set(title='Assigned Group', ylabel='Perceived Motive')
ax.tick_params(top=True, left=True, labeltop=True, bottom=False, labelbottom=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1f3ea62d-9e62-461e-8c65-1caf654509ee' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
